# %% [markdown]
# # Q1) Prepare a classification model using SVM for salary data

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn import metrics
import seaborn as sns
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.plotting import plot_decision_regions

# %% [markdown]
# # Collection of data and description

# %%
test_sal = pd.read_csv('C:\\Users\\DELL\\OneDrive\\Desktop\\DATA SCIENCE\\Datasets\\SalaryData_Test(1).csv')
test_sal
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
train_sal = pd.read_csv('C:\\Users\\DELL\\OneDrive\\Desktop\\DATA SCIENCE\\Datasets\\SalaryData_Train(1).csv')
train_sal
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
df_tmp = test_sal.append(train_sal)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10464\3433121048.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tmp = test_sal.append(train_sal)

# %%
test = test_sal.copy()
train = train_sal.copy()

# %%
test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
str_c = ["workclass","education","maritalstatus","occupation","relationship","race","sex","native"]

# %%
number = LabelEncoder()

# %%
for i in str_c:
    train[i]= number.fit_transform(train[i])
    test[i]=number.fit_transform(test[i])

# %%
test.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          2          1            7              4           6
# 1   38          2         11            9              2           4
# 2   28          1          7           12              2          10
# 3   44          2         15           10              2           6
# 4   34          2          0            6              4           7
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             3     2    1            0            0            40      37
# 1             0     4    1            0            0            50      37
# 2             0     4    1            0            0            40      37
# 3             0     2    1         7688            0            40      37
# 4             1     4    1            0            0            30      37
#
#    Salary
# 0   <=50K
# 1   <=50K
# 2    >50K
# 3    >50K
# 4   <=50K

# %%
train.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4
#
#    Salary
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %%
mapping = {' >50K': 1, ' <=50K': 2}

# %%
train = train.replace({'Salary': mapping})
test = test.replace({'Salary': mapping})

# %%
df = train.append(test)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10464\2767323617.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = train.append(test)

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4
#
#    Salary
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2

# %%
df1.shape
# Out:
# (45221, 14)

# %%
df1.describe().T
# Out:
#                  count         mean          std   min   25%   50%   75%  \
# age            45221.0    38.548086    13.217981  17.0  28.0  37.0  47.0
# workclass      45221.0     2.204507     0.958132   0.0   2.0   2.0   2.0
# education      45221.0    10.313217     3.816992   0.0   9.0  11.0  12.0
# educationno    45221.0    10.118463     2.552909   1.0   9.0  10.0  13.0
# maritalstatus  45221.0     2.585148     1.500460   0.0   2.0   2.0   4.0
# occupation     45221.0     5.969572     4.026444   0.0   2.0   6.0   9.0
# relationship   45221.0     1.412684     1.597242   0.0   0.0   1.0   3.0
# race           45221.0     3.680281     0.832361   0.0   4.0   4.0   4.0
# sex            45221.0     0.675062     0.468357   0.0   0.0   1.0   1.0
# capitalgain    45221.0  1101.454700  7506.511295   0.0   0.0   0.0   0.0
# capitalloss    45221.0    88.548617   404.838249   0.0   0.0   0.0   0.0
# hoursperweek   45221.0    40.938038    12.007640   1.0  40.0  40.0  45.0
# ...

# %%
df1.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %% [markdown]
# # Finding Correlation

# %%
corr = df1.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = 9,5

# %%
#Finding Duplicate Values
df1[df1.index.duplicated()]
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
#Removing duplicate values
df1 = df1[~df1.index.duplicated()]

# %%
plt.figure(figsize=(16,5))
print("Skew: {}".format(df1['educationno'].skew()))
print("Kurtosis: {}".format(df1['educationno'].kurtosis()))
ax = sns.kdeplot(df1['educationno'],shade=True,color='g')
plt.xticks([i for i in range(0,20,1)])
plt.show()
# Out:
# Skew: -0.305378355820322
# Kurtosis: 0.643604835875955

# %% [raw]
# The Data is negatively skewed and has low kurtosis value
# Most of people have eduction Number of years of education 9 - 10

# %%
dfa = df_tmp[df_tmp.columns[0:13]]
obj_colum = dfa.select_dtypes(include='object').columns.tolist()

# %%
plt.figure(figsize=(16,10))
for i,col in enumerate(obj_colum,1):
    plt.subplot(2,2,i)
    sns.countplot(data=dfa,y=col)
    plt.subplot(2,2,i+2)
    df_tmp[col].value_counts(normalize=True).plot.bar()
    plt.ylabel(col)
    plt.xlabel('% distribution per category')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 2>()
#       3 plt.subplot(2,2,i)
#       4 sns.countplot(data=dfa,y=col)
# ----> 5 plt.subplot(2,2,i+2)
#       6 df_tmp[col].value_counts(normalize=True).plot.bar()
#       7 plt.ylabel(col)
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:1268, in subplot(*args, **kwargs)
#    1265 fig = gcf()
#    1267 # First, search for an existing subplot with a matching spec.
# -> 1268 key = SubplotSpec._from_subplot_args(fig, args)
#    1270 for ax in fig.axes:
#    1271     # if we found an axes at the position sort out if we can re-use it
#    1272     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1273         # if the user passed no kwargs, re-use
#
# File ~\anaconda3\lib\site-packages\matplotlib\gridspec.py:608, in SubplotSpec._from_subplot_args(figure, args)
# ...

# %% [raw]
# Majority of the workclass is in Private Sector
# Also for education mojority of the people have HS graduation or some college degree

# %%
num_columns = dfa.select_dtypes(exclude='object').columns.tolist()

# %%
plt.figure(figsize=(18,40))
for i,col in enumerate(num_columns,1):
    plt.subplot(8,4,i)
    sns.kdeplot(df1[col],color='g',shade=True)
    plt.subplot(8,4,i+10)
    df1[col].plot.box()
plt.tight_layout() 
plt.show()
num_data = df1[num_columns]
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
#               age  educationno  capitalgain  capitalloss  hoursperweek
# skewness  0.53018    -0.305378    11.902483     4.528238      0.330856
# kurtosis -0.14476     0.643605   153.661174    19.529284      3.167683

# %% [markdown]
# # SVM

# %%
col = df1.columns

# %%
x_train = train[col[0:13]]
y_train = train[col[13]]
x_test = test[col[0:13]]
y_test = test[col[13]]

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
x_train = norm_func(x_train)
x_test =  norm_func(x_test)

# %% [markdown]
# # i) Linear method

# %%
model_linear = SVC(kernel = "linear")
model_linear.fit(x_train,y_train)
pred_test_linear = model_linear.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, pred_test_linear))
# Out:
# Accuracy: 0.8097609561752988

# %% [markdown]
# # ii) Poly method

# %%
model_poly = SVC(kernel = "poly")
model_poly.fit(x_train,y_train)
pred_test_poly = model_poly.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, pred_test_poly))
# Out:
# Accuracy: 0.8435590969455511

# %% [markdown]
# # iii)Radial basis function (RBF) method

# %%
model_rbf = SVC(kernel = "rbf")
model_rbf.fit(x_train,y_train)
pred_test_rbf = model_rbf.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, pred_test_rbf))
# Out:
# Accuracy: 0.8432934926958832

# %% [markdown]
# # iv) Sigmoid method

# %%
model_sigmoid = SVC(kernel = "sigmoid")
model_sigmoid.fit(x_train,y_train)
pred_test_sigmoid = model_sigmoid.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, pred_test_sigmoid))
# Out:
# Accuracy: 0.5768924302788845

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Poly model method gives the best accuracy
